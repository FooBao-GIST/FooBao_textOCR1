# %%
from main import PororoOcr

# %% [markdown]
# 최초에 한번은 Model을 다운로드 합니다. 경로는 Windows의 경우 ```C:/pororo/misc```이고 Mac OS의 경우는 ```~/.pororo/misc/``` 입니다.

# %%
ocr = PororoOcr()

# %% [markdown]
# 현재 지원 가능하는 언어는 영어와 한국어 입니다.

# %%
ocr.get_available_langs()
# Out:
# ['en', 'ko']

# %%
ocr.get_available_models()
# Out:
# {'en': ['brainocr'], 'ko': ['brainocr']}

# %% [markdown]
# **Examples**
# ```python
# ocr = Pororo(task='ocr', lang='ko')
# ocr(IMAGE_PATH)
# ```

# %%
img_path = 'menu5.jpeg'

# %%
ocr.run_ocr(img_path, debug=True)
# Out:
# ['ChaR A비ERICAN YIBE, NEW CHINESE',
#  'AMERICAN CHINESE RESTAURANT',
#  'WaprconenToTo USING INGREDIENTS 인 BeeN CARETULLY SELECTEC QUALIT ANDSAFL 후회',
#  'LIGHT DISH sOUp',
#  'CHICKEN PORK',
#  'SET MENU',
#  '공심채 볶음 5th-try Morning Glory 담백한 중화 공심재 볶음 요리',
#  "제네럴 쏘 치킨 Goneral Tuo'e Chickon 달콤, 고소한 대표 미국식 중식 치킨요리",
#  'Cha SET',
#  '전종가지세우 Spcy Garkc Eggplont Shyimp 마라짱뽕 topanc 볶음밥 Fried Rice',
#  '유린기 샐러드 Chichen in Groathek 내시한 테디리살 통권과 야채가 어우러진 자말만이 뒤춧기 샐러드 달리',
#  '오렌지 치킨 Crange Chicke 오렌지 향 대균은 대표 미국식 중식 지킨 요리',
#  '18.5',
#  '마파두부 Mape Totu 머끔한 차말만의 사천식 마파두부',
#  '차알 탕수육 Cha계 Sweet & Sour Park 코쿄넛 슬라이스, 당백 바삭한 차말만의 함수옥',
#  '220',
#  "RSET 제네럴 쏘 치킨 or 오렌지 치킨 GGeneral 1so's Chicken or Cronge Chicken",
#  '차알 순두부 핫팟 CB R 5on 1ou -5 따리와 부대찌개 베이스 옥수, 차일만의 선두부 전골',
#  'RICE NOODLE',
#  '몽골리안비프 Mangolian Boet 차우멘 Chow',
#  "차알 볶음밥. CAV'D Frlied Pcm 담백, 고술찬 부음밥",
#  'BEEF SEAFOOD',
#  '간풍가지새우 Sorn Gufc S 대출한 소스, 가지 안에 새우프 낳온 지말만의 대표 세우 깨곱 요리',
#  '트레이 짜장 (ay EA>C* 360n N00OE 차알만의 고소한 볶음 짜장',
#  "Cha'RSET 간종가지새우: cmt hommant Sm기 차일땅수옥 ChaR Sweet Sour Pork 마라찜뽕 jomppong 볶음밥 Fred Rce",
#  '마라짬뽕',
#  '마라샹궈 M기의 Kwng 깊은 야채, 하물 차알만의 마라상궈요리',
#  '120',
#  '차말타의 | 시그니처 소고기 마리',
#  '차우멘',
#  '로제샹궈 Date Mala Xhang Guo 투제마라스스 크롬소스가 머우러진 자말만의 포제 성',
#  '해스인 해사당 글소스로 뷰이낸 대표 미국식',
#  '먼요리',
#  '차앞 순두부 ChWR SohTA 하데인 보여피% 바이스 뉴스 히락아이 손두부',
#  '몽골리안비프 Mmmnkn 공심채와 부채살용 글스스로 볶아낸 대표 미국식 중식 소고기 요리']

# %%
ocr.get_ocr_result()
# Out:
# {'description': ['파스타 & 리조토 정보파스타 시옹치파스타 엔초비쥬키니알리오올리요 가지를 넣은 화이트라구 파프리카 새우로제 바질페스토 쭈구미올리오 차이나 누들 새치즈 토마토 파스타 크림 미트볼 파스타 토마토 미트볼 파스타 구운토마토 강바스 올리오 바콩마미 미트볼슈튜 RED. 소꼬리스튜 보리리조토 소공창과 먹물리조토 스테이크리조토 & 로데스코쌈캄',
#   '18.000 15.000 13.000 14.000 16.000 14.000 17.000 16.000 15.000 15.000 17.000 16.. 000 29.000 23.000 24.000',
#   '샐러드 & 피자 시트러스 홈치크샐러드 HONESTST 마마스 딥디쉬 미드나잇 블루팜',
#   '14.000 21.000 22,000',
#   '음료 HOT 아메리카노 ICE 아메리카노 콜라 제로콜라 스프라이트 분다버그 honest6t. 2nd instagram',
#   '3.000 3.000 3.000 3.000 3.000 5.000',
#   '5G P.W 1704032447'],
#  'bounding_poly': [{'description': '파스타 & 리조토 정보파스타 시옹치파스타 엔초비쥬키니알리오올리요 가지를 넣은 화이트라구 파프리카 새우로제 바질페스토 쭈구미올리오 차이나 누들 새치즈 토마토 파스타 크림 미트볼 파스타 토마토 미트볼 파스타 구운토마토 강바스 올리오 바콩마미 미트볼슈튜 RED. 소꼬리스튜 보리리조토 소공창과 먹물리조토 스테이크리조토 & 로데스코쌈캄',
#    'vertices': [{'x': 99, 'y': 54},
#     {'x': 425, 'y': 54},
#     {'x': 425, 'y': 658},
#     {'x': 99, 'y': 658}]},
#   {'description': '18.000 15.000 13.000 14.000 16.000 14.000 17.000 16.000 15.000 15.000 17.000 16.. 000 29.000 23.000 24.000',
#    'vertices': [{'x': 722, 'y': 112},
#     {'x': 808, 'y': 112},
#     {'x': 808, 'y': 658},
#     {'x': 722, 'y': 658}]},
#   {'description': '샐러드 & 피자 시트러스 홈치크샐러드 HONESTST 마마스 딥디쉬 미드나잇 블루팜',
#    'vertices': [{'x': 99, 'y': 691},
#     {'x': 561, 'y': 691},
#     {'x': 561, 'y': 869},
#     {'x': 99, 'y': 869}]},
#   {'description': '14.000 21.000 22,000',
#    'vertices': [{'x': 722, 'y': 762},
#     {'x': 806, 'y': 762},
#     {'x': 806, 'y': 862},
#     {'x': 722, 'y': 862}]},
#   {'description': '음료 HOT 아메리카노 ICE 아메리카노 콜라 제로콜라 스프라이트 분다버그 honest6t. 2nd instagram',
#    'vertices': [{'x': 33, 'y': 903},
#     {'x': 290, 'y': 903},
#     {'x': 290, 'y': 1259},
#     {'x': 33, 'y': 1259}]},
#   {'description': '3.000 3.000 3.000 3.000 3.000 5.000',
#    'vertices': [{'x': 732, 'y': 976},
#     {'x': 802, 'y': 976},
#     {'x': 802, 'y': 1190},
#     {'x': 732, 'y': 1190}]},
#   {'description': '5G P.W 1704032447',
#    'vertices': [{'x': 586, 'y': 1204},
#     {'x': 872, 'y': 1204},
#     {'x': 872, 'y': 1257},
#     {'x': 586, 'y': 1257}]}]}
